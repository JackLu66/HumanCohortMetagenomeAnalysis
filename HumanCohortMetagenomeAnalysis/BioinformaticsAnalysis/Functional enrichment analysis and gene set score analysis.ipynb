# %% [markdown]
# Over Representation Analysis (ORA) and Gene Set Enrichment Analysis (GSEA) were analyzed by Clusterprofiler (version 3.1.0) and Metascape (http://metascape.org/gp/index.html) with default parameters. Genes in each gene set are listed in Supplementary Table 9.
